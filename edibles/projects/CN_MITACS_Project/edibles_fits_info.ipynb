# %%
import edibles as ed
import numpy as np
import matplotlib.pyplot as plt
from astropy.io import fits
import glob as g

file = np.sort(g.glob("C:/Users/dell 7430/OneDrive/Desktop/Jan_Project/DR4/HD149757/BLUE_346/*.fits"))
image = fits.open(file[11])

header = image[0].header
data = image[0].data

header
# Out:
# SIMPLE  =                    T / Written by IDL:  Thu Mar 28 21:41:24 2019
# BITPIX  =                  -32 / Bits per pixel
# NAXIS   =                    1 / Number of axes
# NAXIS1  =                 2702 / Axis length
# EXTEND  =                    F / File may contain extensions
# ORIGIN  = 'NOAO-IRAF FITS Image Kernel July 2003' / FITS file originator
# IRAF-TLM= '2019-02-16T22:46:53' / Time of last modification
# OBJECT  = 'HD149757'           / Name of the object observed
# COMMENT   FITS (Flexible Image Transport System) format is defined in 'Astronomy
# COMMENT   and Astrophysics', volume 376, page 359; bibcode: 2001A&A...376..359H
# DATE    = '2019-02-16T22:46:53' / file creation date (YYYY-MM-DDThh:mm:ss UT)
# CTYPE1  = 'LINEAR  '
# CUNIT1  = 'Angstrom'           / Wavelength units
# BUNIT   = 'ADU     '
# CRVAL1  =      3453.5200195312
# CRPIX1  =                   1.
# CDELT1  =    0.019992595335061
# LAMRMS  =             0.000623 / RMS of wavelength solution [CUNIT1]
# ...

# %%
print("Length of data:", len(data))
# Out:
# Length of data: 2702
